# %% [markdown]
# # Doctor Performance Analysis — Notebook walkthrough
#
# This notebook reuses the exact same modules as the Streamlit app.

# %%
from sample_data import generate_mock_dataset
from preprocessing import clean_dataset
from kpi_engine import compute_kpis, monthly_success_trend, specialization_summary
from visualization import bar_top_doctors, line_trend, radar_compare, heatmap_specialization

raw = generate_mock_dataset()
df = clean_dataset(raw)
df.head()

# %% [markdown]
# ## KPIs

# %%
kpis = compute_kpis(df, threshold=60)
kpis.head(10)

# %% [markdown]
# ## Visualizations

# %%
bar_top_doctors(kpis).show()

# %%
line_trend(monthly_success_trend(df)).show()

# %%
heatmap_specialization(kpis).show()

# %%
a, b = kpis.iloc[0].doctor_id, kpis.iloc[-1].doctor_id
radar_compare(kpis, a, b).show()

# %% [markdown]
# ## Summaries & flagged doctors

# %%
specialization_summary(kpis)

# %%
kpis[kpis['flagged']]
